# %%
from __future__ import print_function, division

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %%
x = np.linspace(0,10,100)
plt.plot(x,np.sin(x),x,np.cos(x))

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(dataq[col], normed=True, alpha=0.5)

# %%
sns.kdeplot(pd.Series([1,2,3,2,2,1,5,6,0]))

# %%
#for col in 'xy':
#    sns.kdeplot(data[col],shade=True)
sns.kdeplot(data['x'],shade=True)

# %%
sns.distplot(data['x']);

# %%
sns.kdeplot(data);

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde');

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='hex');

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', size=2.5);

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15));

# %%
with sns.axes_style(style='ticks'):
    g = sns.factorplot("day", "total_bill", "sex", data=tips, kind="box")
    g.set_axis_labels("Day", "Total Bill");

# %%
import seaborn as sns
import pandas as pd
sns.kdeplot(pd.Series([1,2,3,3,3,3,4,5]),shade=True,label="radius = {radius}".format(radius=500))
sns.kdeplot(pd.Series([1,1,1,1,2,3,4,5]),shade=True,label="radius = {radius}".format(radius=1000))
sns.kdeplot(pd.Series([1,2,13,13,13,13,4,5]),shade=True,label="radius = {radius}".format(radius=500))
sns.kdeplot(pd.Series([21,21,21,21,2,3,4,5]),shade=True,label="radius = {radius}".format(radius=1000))

# %%
sns.set(style="whitegrid")
df=pd.DataFrame(np.random.randn(110,5),columns=['one','two','three','four','five'])
sns.violinplot(df,label="radius = {radius}".format(radius=500),inner="points")

#sns.kdeplot(pd.Series([1,1,1,1,2,3,4,5]),shade=True,label="radius = {radius}".format(radius=1000)

# %%
sns.violinplot(df,color="Set3", bw=.2, cut=.6,
               lw=.5, inner="points", inner_kws={"ms": 6})
